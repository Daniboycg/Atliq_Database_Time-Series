# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 30)
pd.options.display.float_format='{:,.2f}'.format
df = pd.read_csv('../../data/interim/LATAM_mar-dec.csv')
df.head()
# Out:
#                 customer        platform   channel  market        date
# 0          Atliq e Store      E-Commerce    Direct  Brazil  2021-03-01  \
# 1  Electricalsbea Stores  Brick & Mortar  Retailer   Chile  2021-03-01
# 2                Amazon       E-Commerce  Retailer   Chile  2021-03-01
# 3                Amazon       E-Commerce  Retailer  Mexico  2021-03-01
# 4                Amazon       E-Commerce  Retailer  Brazil  2021-03-01
#
#    sold_quantity division      segment      category          product
# 0              4    P & A  Peripherals  Graphic Card  AQ Mforce Gen X  \
# 1              1    P & A  Peripherals  Graphic Card  AQ Mforce Gen X
# 2              3    P & A  Peripherals  Graphic Card  AQ Mforce Gen X
# 3              6    P & A  Peripherals  Graphic Card  AQ Mforce Gen X
# 4              5    P & A  Peripherals  Graphic Card  AQ Mforce Gen X
#
#       variant  total_gross_sales
# 0  Standard 3              78.09
# 1  Standard 3              19.52
# 2  Standard 3              58.57
# 3  Standard 3             117.14
# 4  Standard 3              97.62
